# %%
from sklearn.datasets import load_breast_cancer

dataset = load_breast_cancer()
X = dataset.data
Y = dataset.target

# %%
from sklearn.model_selection import train_test_split
X_TRAIN, X_TEST, Y_TRAIN, Y_TEST = train_test_split(X, Y, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_TRAIN = scaler.fit_transform(X_TRAIN)
X_TEST = scaler.transform(X_TEST)

# %%
from sklearn.linear_model import LogisticRegression
algorithm = LogisticRegression()

# %%
algorithm.fit(X_TRAIN,Y_TRAIN)
# Out:
# LogisticRegression()

# %%
Y_PRED = algorithm.predict(X_TEST)

# %%
from matplotlib import pyplot as plt
plt.plot(Y_PRED)
plt.plot(Y_TEST)
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
print('Confusion matrix')
matrix = confusion_matrix(Y_TEST, Y_PRED)
ConfusionMatrixDisplay(matrix).plot()
plt.show
# Out:
# Confusion matrix
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.metrics import precision_score
print(f'precision of the algorithm: {precision_score(Y_TEST,Y_PRED)}')
# Out:
# precision of the algorithm: 0.9864864864864865

# %%
from sklearn.metrics import accuracy_score
print(f'accuracy of the algorithm: {accuracy_score(Y_TEST,Y_PRED)}')
# Out:
# accuracy of the algorithm: 0.9824561403508771
