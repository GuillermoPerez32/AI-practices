# %%
import face_recognition
image = face_recognition.load_image_file("selfies.jpg")

# %%
from matplotlib import pyplot as plt
plt.imshow(image)
plt.show()

# %%
face_locations = face_recognition.face_locations(image) #face locations
print(f'Cantidad de caras: {len(face_locations)}')
# Out:
# Cantidad de caras: 5

# %%
from PIL import Image
for face_location in face_locations:

    # Print the location of each face in this image
    top, right, bottom, left = face_location
    # print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # You can access the actual face itself like this:
    face_image = image[top:bottom, left:right]
    plt.imshow(face_image)
    plt.show()
# Out:
# A face is located at pixel location Top: 113, Left: 245, Bottom: 164, Right: 296
# A face is located at pixel location Top: 87, Left: 170, Bottom: 149, Right: 232
# A face is located at pixel location Top: 90, Left: 302, Bottom: 141, Right: 354
# A face is located at pixel location Top: 26, Left: 279, Bottom: 78, Right: 331
# A face is located at pixel location Top: 53, Left: 100, Bottom: 115, Right: 163
